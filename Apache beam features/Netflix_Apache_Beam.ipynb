# %% [markdown]
# <a href="https://colab.research.google.com/github/hvr2026/Apache-Beam-Data-Engineering/blob/main/Apache%20beam%20features/Netflix_Apache_Beam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install Apache Beam and pandas
# !pip install apache-beam[gcp] pandas --quiet

# %%
# Import required libraries
import os
import apache_beam as beam
from apache_beam.options.pipeline_options import PipelineOptions
import pandas as pd
import json
import matplotlib.pyplot as plt
from collections import Counter

# %%
# Step 3: Define a custom ParDo for preprocessing
class PreprocessData(beam.DoFn):
    def process(self, element):
        try:
            record = json.loads(element)
            return [{
                'title': record.get('title', ''),
                'release_year': int(record.get('release_year', 0)) if record.get('release_year') else None,
                'duration': record.get('duration', ''),
                'type': record.get('type', '')
            }]
        except Exception as e:
            print(f"Error processing record: {e}")
            return []

# %%
# Step 4: Composite Transform - Extract Movies
class ExtractMovies(beam.PTransform):
    def expand(self, pcoll):
        return (
            pcoll
            | "Filter Movies" >> beam.Filter(lambda record: record and record.get('type') == 'Movie')
            | "Extract Movie Details" >> beam.Map(lambda record: {
                'title': record['title'],
                'release_year': record['release_year'],
                'duration': record['duration']
            })
        )

# %%
# Step 5: Simulate Streaming Data Source from the Netflix dataset
def generate_stream_data(file_path):
    if not os.path.exists(file_path):
        print(f"Error: File {file_path} not found. Ensure the file is in the correct location.")
        return []

    df = pd.read_csv(file_path)
    for _, row in df.iterrows():
        yield json.dumps(row.to_dict())  # Convert each row to JSON for processing

# %%
# Step 6: Visualization Helper Function
def plot_release_year_distribution(data):
    if not data:
        print("No data to visualize.")
        return

    years = [record['release_year'] for record in data if record.get('release_year')]
    year_counts = Counter(years)
    plt.bar(year_counts.keys(), year_counts.values())
    plt.xlabel("Release Year")
    plt.ylabel("Count")
    plt.title("Distribution of Release Years")
    plt.show()

# %%
# Step 7: Run the Apache Beam pipeline
def run_pipeline(file_path):
    if not os.path.exists(file_path):
        print(f"Error: File {file_path} not found. Please provide a valid file.")
        return

    options = PipelineOptions(streaming=False, save_main_session=True)
    collected_data = []

    with beam.Pipeline(options=options) as pipeline:
        # Step 7.1: Generate streaming data from the dataset
        raw_stream = (
            pipeline
            | "Generate Streaming Data" >> beam.Create(list(generate_stream_data(file_path)))
        )

        # Step 7.2: Apply ParDo for preprocessing
        preprocessed_data = (
            raw_stream
            | "Preprocess Data" >> beam.ParDo(PreprocessData())
            | "Filter None Values" >> beam.Filter(lambda record: record is not None)  # Filter None
            | "Debug Preprocessed Data" >> beam.Map(print)  # Debug Preprocessed Data
        )

        # Step 7.3: Apply composite transform to extract movie data
        movies_data = (
            preprocessed_data
            | "Extract Movies" >> ExtractMovies()
            | "Debug Movies Data" >> beam.Map(print)  # Debug Movies Data
        )

# %%
# Step 8: Execute the pipeline with the Netflix dataset
file_path = "/content/netflix_titles.csv"  # Update to the correct path for your dataset
run_pipeline(file_path)
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-8d8a3076-e034-4a1b-9a1f-a7f0174a65d3.json']
# Streaming output truncated to the last 5000 lines.
# {'title': 'Rosario Tijeras', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': '1994', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Born in Gaza', 'release_year': 2014, 'duration': '70 min', 'type': 'Movie'}
# {'title': 'Born in Syria', 'release_year': 2016, 'duration': '87 min', 'type': 'Movie'}
# {'title': 'Dying to Tell', 'release_year': 2018, 'duration': '88 min', 'type': 'Movie'}
# {'title': "It's Bruno!", 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Maria', 'release_year': 2019, 'duration': '90 min', 'type': 'Movie'}
# {'title': "ReMastered: The Lion's Share", 'release_year': 2019, 'duration': '84 min', 'type': 'Movie'}
# {'title': 'Saverio Raimondo: Il Satiro Parlante', 'release_year': 2019, 'duration': '53 min', 'type': 'Movie'}
# {'title': 'See You Yesterday', 'release_year': 2019, 'duration': '87 min', 'type': 'Movie'}
# {'title': 'White Gold', 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Good Sam', 'release_year': 2019, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Jonaki', 'release_year': 2018, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'PATRICK (2019)', 'release_year': 2019, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Dennis and Gnasher Unleashed', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Hamid', 'release_year': 2018, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Heidi, bienvenida a casa', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'I Hear You', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Backdraft 2', 'release_year': 2019, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'Revisions', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Still LAUGH-IN: The Stars Celebrate', 'release_year': 2019, 'duration': '61 min', 'type': 'Movie'}
# {'title': 'Weed the People', 'release_year': 2018, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Malibu Rescue', 'release_year': 2019, 'duration': '70 min', 'type': 'Movie'}
# {'title': 'Merata: How Mum Decolonised the Screen', 'release_year': 2018, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'The Defected', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Dry Martina', 'release_year': 2018, 'duration': '100 min', 'type': 'Movie'}
# {'title': 'Shéhérazade', 'release_year': 2019, 'duration': '111 min', 'type': 'Movie'}
# {'title': 'The Great Magician', 'release_year': 2011, 'duration': '128 min', 'type': 'Movie'}
# {'title': 'Easy', 'release_year': 2019, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'In Family I Trust', 'release_year': 2018, 'duration': '98 min', 'type': 'Movie'}
# {'title': 'Jailbirds', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Mechanism', 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'The Princess Weiyoung', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Society', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Wine Country', 'release_year': 2019, 'duration': '104 min', 'type': 'Movie'}
# {'title': 'Gatao 2: Rise of the King', 'release_year': 2018, 'duration': '126 min', 'type': 'Movie'}
# {'title': 'Away From Home', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Bibik-Bibikku', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Cinta 100KG', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Cinta Iris', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Cinta Si Wedding Planner', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Cinta Teruna Kimchi', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Secret of Success', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Missing Menu', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Unchained Fate', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Abyss', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'I Have a Script', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'In the Bosom of a Thorn', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Writer', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'What If?', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Last Breath', 'release_year': 2019, 'duration': '86 min', 'type': 'Movie'}
# {'title': 'The Wandering Earth', 'release_year': 2019, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'All In My Family', 'release_year': 2019, 'duration': '40 min', 'type': 'Movie'}
# {'title': 'Crime Diaries: Night Out', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Cupcake & Dino - General Services', 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Despite Everything', 'release_year': 2019, 'duration': '79 min', 'type': 'Movie'}
# {'title': 'Extremely Wicked, Shockingly Evil and Vile', 'release_year': 2019, 'duration': '110 min', 'type': 'Movie'}
# {'title': 'Flinch', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Jo Pil-ho: The Dawning Rage', 'release_year': 2018, 'duration': '128 min', 'type': 'Movie'}
# {'title': 'The Last Summer', 'release_year': 2019, 'duration': '110 min', 'type': 'Movie'}
# {'title': 'Tuca & Bertie', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Laatu', 'release_year': 2018, 'duration': '116 min', 'type': 'Movie'}
# {'title': 'Olympus Has Fallen', 'release_year': 2013, 'duration': '119 min', 'type': 'Movie'}
# {'title': 'Code Geass: Lelouch of the Rebellion', 'release_year': 2008, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'John & Yoko: Above Us Only Sky', 'release_year': 2018, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Knock Down The House', 'release_year': 2019, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'Munafik 2', 'release_year': 2018, 'duration': '104 min', 'type': 'Movie'}
# {'title': 'Sur Sapata', 'release_year': 2019, 'duration': '140 min', 'type': 'Movie'}
# {'title': 'A Home with A View', 'release_year': 2019, 'duration': '92 min', 'type': 'Movie'}
# {'title': "Angel 'N' Devil", 'release_year': 2014, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Anthony Jeselnik: Fire in the Maternity Ward', 'release_year': 2019, 'duration': '64 min', 'type': 'Movie'}
# {'title': 'Hong Kong West Side Stories', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Ingress: The Animation', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'K.O. One Re-act', 'release_year': 2013, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'K.O.3an Guo', 'release_year': 2009, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'KO One Return', 'release_year': 2012, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Outsiders', 'release_year': 2004, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Ash vs. Evil Dead', 'release_year': 2018, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Teen Aur Aadha', 'release_year': 2018, 'duration': '119 min', 'type': 'Movie'}
# {'title': 'Señora Acero', 'release_year': 2018, 'duration': '5 Seasons', 'type': 'TV Show'}
# {'title': 'Chambers', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Loving is Losing', 'release_year': 2019, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'Money Trap', 'release_year': 2019, 'duration': '122 min', 'type': 'Movie'}
# {'title': 'Njan Prakashan', 'release_year': 2018, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'ReMastered: Devil at the Crossroads', 'release_year': 2019, 'duration': '49 min', 'type': 'Movie'}
# {'title': 'Street Food', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Hateful Eight: Extended Version', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'A Fortunate Man', 'release_year': 2018, 'duration': '168 min', 'type': 'Movie'}
# {'title': 'Grass Is Greener', 'release_year': 2019, 'duration': '98 min', 'type': 'Movie'}
# {'title': 'Brené Brown: The Call to Courage', 'release_year': 2019, 'duration': '77 min', 'type': 'Movie'}
# {'title': 'KO One', 'release_year': 2005, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Lunatics', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Music Teacher', 'release_year': 2019, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'My Dear Boy', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Rilakkuma and Kaoru', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Samantha!', 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Someone Great', 'release_year': 2019, 'duration': '92 min', 'type': 'Movie'}
# {'title': 'The Ruthless', 'release_year': 2019, 'duration': '111 min', 'type': 'Movie'}
# {'title': 'A Little Chaos', 'release_year': 2014, 'duration': '113 min', 'type': 'Movie'}
# {'title': 'Franco Escamilla: Bienvenido al mundo', 'release_year': 2019, 'duration': '54 min', 'type': 'Movie'}
# {'title': 'HOMECOMING: A film by Beyoncé', 'release_year': 2019, 'duration': '138 min', 'type': 'Movie'}
# {'title': 'About Time', 'release_year': 2013, 'duration': '123 min', 'type': 'Movie'}
# {'title': 'Super Monsters Furever Friends', 'release_year': 2019, 'duration': '59 min', 'type': 'Movie'}
# {'title': 'Bollywood Calling', 'release_year': 2001, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'Ek Khiladi Ek Haseena', 'release_year': 2005, 'duration': '141 min', 'type': 'Movie'}
# {'title': 'Generation Iron 3', 'release_year': 2018, 'duration': '95 min', 'type': 'Movie'}
# {'title': 'Hazaaron Khwaishein Aisi', 'release_year': 2003, 'duration': '111 min', 'type': 'Movie'}
# {'title': 'Jhankaar Beats', 'release_year': 2003, 'duration': '131 min', 'type': 'Movie'}
# {'title': 'Mumbai Matinee', 'release_year': 2003, 'duration': '116 min', 'type': 'Movie'}
# {'title': 'Rainbow Jelly', 'release_year': 2018, 'duration': '119 min', 'type': 'Movie'}
# {'title': 'Shabd', 'release_year': 2005, 'duration': '146 min', 'type': 'Movie'}
# {'title': 'Shortcut Safari', 'release_year': 2016, 'duration': '101 min', 'type': 'Movie'}
# {'title': 'Thriller', 'release_year': 2018, 'duration': '87 min', 'type': 'Movie'}
# {'title': 'Crazy Ex-Girlfriend', 'release_year': 2019, 'duration': '4 Seasons', 'type': 'TV Show'}
# {'title': 'Who Would You Take to a Deserted Island?', 'release_year': 2019, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Dabbe 5: Zehr-i Cin', 'release_year': 2014, 'duration': '133 min', 'type': 'Movie'}
# {'title': 'Dabbe: The Possession', 'release_year': 2013, 'duration': '135 min', 'type': 'Movie'}
# {'title': 'Francesco De Carlo: Cose di Questo Mondo', 'release_year': 2019, 'duration': '61 min', 'type': 'Movie'}
# {'title': 'Huge in France', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Perfect Date', 'release_year': 2019, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'New Girl', 'release_year': 2018, 'duration': '7 Seasons', 'type': 'TV Show'}
# {'title': 'Persona', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Liss Pereira: Reteniendo líquidos', 'release_year': 2019, 'duration': '59 min', 'type': 'Movie'}
# {'title': 'The Silence', 'release_year': 2019, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'You vs. Wild', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Sarvam Thaala Mayam (Telugu Version)', 'release_year': 2018, 'duration': '131 min', 'type': 'Movie'}
# {'title': 'Petta (Telugu Version)', 'release_year': 2019, 'duration': '170 min', 'type': 'Movie'}
# {'title': 'Time: The Kalief Browder Story', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Alien Warfare', 'release_year': 2019, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'Derek', 'release_year': 2015, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Imposters', 'release_year': 2017, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Our Planet', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Petta', 'release_year': 2019, 'duration': '170 min', 'type': 'Movie'}
# {'title': 'Quicksand', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Rimba Racer', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Roman Empire: Reign of Blood', 'release_year': 2019, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Spirit: Riding Free', 'release_year': 2019, 'duration': '8 Seasons', 'type': 'TV Show'}
# {'title': 'Tijuana', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Unicorn Store', 'release_year': 2019, 'duration': '92 min', 'type': 'Movie'}
# {'title': 'Possessed', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Ricardo Quevedo: Los amargados somos más', 'release_year': 2019, 'duration': '59 min', 'type': 'Movie'}
# {'title': 'Suzzanna: Buried Alive', 'release_year': 2018, 'duration': '126 min', 'type': 'Movie'}
# {'title': 'Tango', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Ek Ladki Ko Dekha Toh Aisa Laga', 'release_year': 2019, 'duration': '120 min', 'type': 'Movie'}
# {'title': 'Jagat', 'release_year': 2015, 'duration': '76 min', 'type': 'Movie'}
# {'title': 'Kevin Hart: Irresponsible', 'release_year': 2019, 'duration': '60 min', 'type': 'Movie'}
# {'title': 'Kicko & Super Speedo', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Love O2O', 'release_year': 2016, 'duration': '103 min', 'type': 'Movie'}
# {'title': 'Pinky Memsaab', 'release_year': 2018, 'duration': '124 min', 'type': 'Movie'}
# {'title': 'That Winter, the Wind Blows', 'release_year': 2013, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Trap', 'release_year': 2017, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'Ultraman', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Mercy Black', 'release_year': 2019, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'The Burial of Kojo', 'release_year': 2018, 'duration': '81 min', 'type': 'Movie'}
# {'title': 'Pablo', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': '15 August', 'release_year': 2019, 'duration': '124 min', 'type': 'Movie'}
# {'title': 'Bayonet', 'release_year': 2019, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'Osmosis', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Santa Clarita Diet', 'release_year': 2019, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'The Highwaymen', 'release_year': 2019, 'duration': '132 min', 'type': 'Movie'}
# {'title': 'The Legend of Cocaine Island', 'release_year': 2019, 'duration': '87 min', 'type': 'Movie'}
# {'title': 'The Terminal', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Traitors', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Versailles', 'release_year': 2018, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Ainori Love Wagon: Asian Journey', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Danur: I Can See Ghosts', 'release_year': 2017, 'duration': '75 min', 'type': 'Movie'}
# {'title': 'Verses of Love', 'release_year': 2008, 'duration': '126 min', 'type': 'Movie'}
# {'title': 'Nate Bargatze: The Tennessee Kid', 'release_year': 2019, 'duration': '61 min', 'type': 'Movie'}
# {'title': 'Sei', 'release_year': 2018, 'duration': '126 min', 'type': 'Movie'}
# {'title': "The Eagle of El-Se'eed", 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Superlopez', 'release_year': 2018, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Oversize Cops', 'release_year': 2017, 'duration': '100 min', 'type': 'Movie'}
# {'title': "Charlie's Colorforms City", 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Crime Diaries: The Candidate', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Delhi Crime', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Mirage', 'release_year': 2018, 'duration': '129 min', 'type': 'Movie'}
# {'title': 'ReMastered: The Miami Showband Massacre', 'release_year': 2019, 'duration': '71 min', 'type': 'Movie'}
# {'title': 'The 10 Sins', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Dirt', 'release_year': 2019, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'The OA', 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Antoine Griezmann: The Making of a Legend', 'release_year': 2019, 'duration': '60 min', 'type': 'Movie'}
# {'title': 'Bo on the Go!', 'release_year': 2007, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Stay Tuned!', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Amazing Praybeyt Benjamin', 'release_year': 2014, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'The Super Parental Guardians', 'release_year': 2016, 'duration': '115 min', 'type': 'Movie'}
# {'title': 'The Third Party', 'release_year': 2016, 'duration': '118 min', 'type': 'Movie'}
# {'title': 'The Unmarried Wife', 'release_year': 2016, 'duration': '130 min', 'type': 'Movie'}
# {'title': 'Vince and Kath and James', 'release_year': 2016, 'duration': '115 min', 'type': 'Movie'}
# {'title': 'Alexis Viera: A Story of Surviving', 'release_year': 2019, 'duration': '69 min', 'type': 'Movie'}
# {'title': 'February 9', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Imago', 'release_year': 2018, 'duration': '97 min', 'type': 'Movie'}
# {'title': "My Husband Won't Fit", 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Amy Schumer Growing', 'release_year': 2019, 'duration': '61 min', 'type': 'Movie'}
# {'title': '5 Flights Up', 'release_year': 2014, 'duration': '92 min', 'type': 'Movie'}
# {'title': 'Green Door', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Bombairiya', 'release_year': 2018, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Burn Out', 'release_year': 2017, 'duration': '104 min', 'type': 'Movie'}
# {'title': 'Edoardo Ferrario: Temi Caldi', 'release_year': 2019, 'duration': '65 min', 'type': 'Movie'}
# {'title': 'Girl', 'release_year': 2018, 'duration': '106 min', 'type': 'Movie'}
# {'title': "If I Hadn't Met You", 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Jeff Dunham: Arguing with Myself', 'release_year': 2006, 'duration': '69 min', 'type': 'Movie'}
# {'title': 'Jeff Dunham: Controlled Chaos', 'release_year': 2011, 'duration': '97 min', 'type': 'Movie'}
# {'title': 'Jeff Dunham: Minding the Monsters', 'release_year': 2012, 'duration': '80 min', 'type': 'Movie'}
# {'title': "Jeff Dunham's Very Special Christmas Special", 'release_year': 2008, 'duration': '85 min', 'type': 'Movie'}
# {'title': 'Late Life: The Chien-Ming Wang Story', 'release_year': 2018, 'duration': '98 min', 'type': 'Movie'}
# {'title': 'My Pride', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Paskal', 'release_year': 2018, 'duration': '115 min', 'type': 'Movie'}
# {'title': 'Robozuna', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'The Disappearance of Madeleine McCann', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Turn Up Charlie', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'A Love Story', 'release_year': 2007, 'duration': '117 min', 'type': 'Movie'}
# {'title': 'Barcelona: A Love Untold', 'release_year': 2016, 'duration': '132 min', 'type': 'Movie'}
# {'title': 'Everything About Her', 'release_year': 2016, 'duration': '127 min', 'type': 'Movie'}
# {'title': 'Finally Found Someone', 'release_year': 2017, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'Seven Sundays', 'release_year': 2017, 'duration': '128 min', 'type': 'Movie'}
# {'title': 'More to Say', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Land of Hypocrisy', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Triple Frontier', 'release_year': 2019, 'duration': '126 min', 'type': 'Movie'}
# {'title': 'Jimmy Carr: The Best of Ultimate Gold Greatest Hits', 'release_year': 2019, 'duration': '58 min', 'type': 'Movie'}
# {'title': 'Eugenie Nights', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'This Evening', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Into the Badlands', 'release_year': 2018, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Bangkok Love Stories: Hey You!', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Disappearance', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Hajwala 2: Mysterious Mission', 'release_year': 2018, 'duration': '116 min', 'type': 'Movie'}
# {'title': 'Immortals', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Juanita', 'release_year': 2019, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Lady J', 'release_year': 2019, 'duration': '111 min', 'type': 'Movie'}
# {'title': 'The Confrontation', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Walk. Ride. Rodeo.', 'release_year': 2019, 'duration': '100 min', 'type': 'Movie'}
# {'title': 'Nappily Ever After', 'release_year': 2018, 'duration': '99 min', 'type': 'Movie'}
# {'title': 'Sisterakas', 'release_year': 2012, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'Starting Over Again', 'release_year': 2014, 'duration': '128 min', 'type': 'Movie'}
# {'title': 'That Thing Called Tadhana', 'release_year': 2015, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'The Love Affair', 'release_year': 2015, 'duration': '127 min', 'type': 'Movie'}
# {'title': 'American Crime Story: The People v. O.J. Simpson', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Secret City', 'release_year': 2016, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'A Korean Odyssey', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Hard Way', 'release_year': 2019, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Everyday I Love You', 'release_year': 2015, 'duration': '124 min', 'type': 'Movie'}
# {'title': 'No Other Woman', 'release_year': 2011, 'duration': '103 min', 'type': 'Movie'}
# {'title': "River's Edge", 'release_year': 2018, 'duration': '118 min', 'type': 'Movie'}
# {'title': 'Sarkar', 'release_year': 2018, 'duration': '162 min', 'type': 'Movie'}
# {'title': 'Weapon of Choice', 'release_year': 2018, 'duration': '89 min', 'type': 'Movie'}
# {'title': '2,215', 'release_year': 2018, 'duration': '89 min', 'type': 'Movie'}
# {'title': "BNK48: Girls Don't Cry", 'release_year': 2018, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Budapest', 'release_year': 2018, 'duration': '103 min', 'type': 'Movie'}
# {'title': 'Cricket Fever: Mumbai Indians', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Larva Island', 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Losers', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Northern Rescue', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Pants on Fire', 'release_year': 2014, 'duration': '87 min', 'type': 'Movie'}
# {'title': 'Paranormal Investigation', 'release_year': 2018, 'duration': '93 min', 'type': 'Movie'}
# {'title': 'Radio Rebel', 'release_year': 2012, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Sarvam Thaala Mayam (Tamil Version)', 'release_year': 2018, 'duration': '131 min', 'type': 'Movie'}
# {'title': 'The Boy Who Harnessed the Wind', 'release_year': 2019, 'duration': '114 min', 'type': 'Movie'}
# {'title': 'The Disastrous Life of Saiki K.', 'release_year': 2018, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'The Last Runway', 'release_year': 2018, 'duration': '107 min', 'type': 'Movie'}
# {'title': 'The Spiderwick Chronicles', 'release_year': 2008, 'duration': '97 min', 'type': 'Movie'}
# {'title': 'Your Son', 'release_year': 2018, 'duration': '103 min', 'type': 'Movie'}
# {'title': 'Quién te cantará', 'release_year': 2018, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'A Second Chance', 'release_year': 2015, 'duration': '130 min', 'type': 'Movie'}
# {'title': 'Beauty and the Bestie', 'release_year': 2015, 'duration': '119 min', 'type': 'Movie'}
# {'title': 'Bride For Rent', 'release_year': 2014, 'duration': '110 min', 'type': 'Movie'}
# {'title': "Can't Help Falling in Love", 'release_year': 2017, 'duration': '120 min', 'type': 'Movie'}
# {'title': 'Evening Shadows', 'release_year': 2018, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'Four Sisters and a Wedding', 'release_year': 2013, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'It Takes a Man and a Woman', 'release_year': 2013, 'duration': '127 min', 'type': 'Movie'}
# {'title': 'My Ex & Whys', 'release_year': 2017, 'duration': '121 min', 'type': 'Movie'}
# {'title': "She's Dating the Gangster", 'release_year': 2014, 'duration': '113 min', 'type': 'Movie'}
# {'title': 'The Breakup Playlist', 'release_year': 2015, 'duration': '118 min', 'type': 'Movie'}
# {'title': 'The Mistress', 'release_year': 2012, 'duration': '132 min', 'type': 'Movie'}
# {'title': 'Unsolved', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Zach Galifianakis: Live at the Purple Onion', 'release_year': 2006, 'duration': '61 min', 'type': 'Movie'}
# {'title': 'Life of An Outcast', 'release_year': 2018, 'duration': '80 min', 'type': 'Movie'}
# {'title': 'The Photographer Of Mauthausen', 'release_year': 2018, 'duration': '110 min', 'type': 'Movie'}
# {'title': 'Bert Kreischer: The Machine', 'release_year': 2016, 'duration': '70 min', 'type': 'Movie'}
# {'title': "Chef's Table", 'release_year': 2019, 'duration': '6 Seasons', 'type': 'TV Show'}
# {'title': 'Firebrand', 'release_year': 2019, 'duration': '117 min', 'type': 'Movie'}
# {'title': 'Paddleton', 'release_year': 2019, 'duration': '89 min', 'type': 'Movie'}
# {'title': 'Paris Is Us', 'release_year': 2019, 'duration': '84 min', 'type': 'Movie'}
# {'title': 'Shonar Pahar', 'release_year': 2018, 'duration': '131 min', 'type': 'Movie'}
# {'title': 'The Big Family Cooking Showdown', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Z4', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'The Drug King', 'release_year': 2018, 'duration': '139 min', 'type': 'Movie'}
# {'title': 'Kevin James: Sweat the Small Stuff', 'release_year': 2001, 'duration': '42 min', 'type': 'Movie'}
# {'title': 'Transformer', 'release_year': 2017, 'duration': '79 min', 'type': 'Movie'}
# {'title': 'Genius', 'release_year': 2018, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'Black Sea', 'release_year': 2015, 'duration': '114 min', 'type': 'Movie'}
# {'title': 'Studio 54', 'release_year': 2018, 'duration': '99 min', 'type': 'Movie'}
# {'title': 'Awe', 'release_year': 2018, 'duration': '111 min', 'type': 'Movie'}
# {'title': 'Ayana', 'release_year': 2017, 'duration': '112 min', 'type': 'Movie'}
# {'title': 'Behind the Curve', 'release_year': 2018, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'Buddies', 'release_year': 2012, 'duration': '103 min', 'type': 'Movie'}
# {'title': 'Candyflip', 'release_year': 2017, 'duration': '104 min', 'type': 'Movie'}
# {'title': 'Chameli', 'release_year': 2004, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'Fatso', 'release_year': 2012, 'duration': '97 min', 'type': 'Movie'}
# {'title': 'Hjørdis', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': "Larry Charles' Dangerous World of Comedy", 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Neevevaro', 'release_year': 2018, 'duration': '132 min', 'type': 'Movie'}
# {'title': 'Pyaar Ke Side Effects', 'release_year': 2006, 'duration': '120 min', 'type': 'Movie'}
# {'title': 'Sur: The Melody of Life', 'release_year': 2002, 'duration': '137 min', 'type': 'Movie'}
# {'title': 'The 43', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Breaker Upperers', 'release_year': 2018, 'duration': '82 min', 'type': 'Movie'}
# {'title': 'The Kirlian Frequency', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Ugly Aur Pagli', 'release_year': 2008, 'duration': '115 min', 'type': 'Movie'}
# {'title': 'Yucatán', 'release_year': 2018, 'duration': '130 min', 'type': 'Movie'}
# {'title': 'Barbie Dreamhouse Adventures', 'release_year': 2018, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Ken Jeong: You Complete Me, Ho', 'release_year': 2019, 'duration': '62 min', 'type': 'Movie'}
# {'title': 'Velvet Colección', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Period. End of Sentence.', 'release_year': 2018, 'duration': '26 min', 'type': 'Movie'}
# {'title': 'Iron Ladies', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Break', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'High Flying Bird', 'release_year': 2019, 'duration': '91 min', 'type': 'Movie'}
# {'title': "Kevin Hart's Guide to Black History", 'release_year': 2019, 'duration': '63 min', 'type': 'Movie'}
# {'title': 'One Day at a Time', 'release_year': 2019, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'ReMastered: The Two Killings of Sam Cooke', 'release_year': 2019, 'duration': '74 min', 'type': 'Movie'}
# {'title': 'The Tree of Blood', 'release_year': 2018, 'duration': '136 min', 'type': 'Movie'}
# {'title': 'The Last of the Schmucks', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Hidden Worlds', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Live', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Ray Romano: Right Here, Around the Corner', 'release_year': 2019, 'duration': '59 min', 'type': 'Movie'}
# {'title': 'Safe', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Tayee', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Violet Evergarden', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Romance is a bonus book', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Await Further Instructions', 'release_year': 2018, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'Manusangada', 'release_year': 2017, 'duration': '93 min', 'type': 'Movie'}
# {'title': '14 Minutes from Earth', 'release_year': 2016, 'duration': '84 min', 'type': 'Movie'}
# {'title': 'Dear Ex', 'release_year': 2018, 'duration': '100 min', 'type': 'Movie'}
# {'title': "Free Rein: Valentine's Day", 'release_year': 2019, 'duration': '51 min', 'type': 'Movie'}
# {'title': 'Lego DC Comics: Batman Be-Leaguered', 'release_year': 2014, 'duration': '22 min', 'type': 'Movie'}
# {'title': 'LEGO Marvel Super Heroes: Black Panther', 'release_year': 2018, 'duration': '22 min', 'type': 'Movie'}
# {'title': 'LEGO Marvel Super Heroes: Guardians of the Galaxy', 'release_year': 2017, 'duration': '22 min', 'type': 'Movie'}
# {'title': 'Littlest Pet Shop: A World of Our Own', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Russian Doll', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Sparta', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Sword Art Online Alternative: Gun Gale Online', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'True: Happy Hearts Day', 'release_year': 2019, 'duration': '24 min', 'type': 'Movie'}
# {'title': 'Velvet Buzzsaw', 'release_year': 2019, 'duration': '113 min', 'type': 'Movie'}
# {'title': 'Hantu Kak Limah', 'release_year': 2018, 'duration': '110 min', 'type': 'Movie'}
# {'title': 'Love Off the Cuff', 'release_year': 2017, 'duration': '120 min', 'type': 'Movie'}
# {'title': 'Paprika', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Maharaja: The Story of Ranjit Singh', 'release_year': 2010, 'duration': '56 min', 'type': 'Movie'}
# {'title': 'Virsa', 'release_year': 2010, 'duration': '127 min', 'type': 'Movie'}
# {'title': 'Bhasmasur', 'release_year': 2017, 'duration': '74 min', 'type': 'Movie'}
# {'title': 'Gabriel "Fluffy" Iglesias: One Show Fits All', 'release_year': 2019, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'High Society', 'release_year': 2018, 'duration': '137 min', 'type': 'Movie'}
# {'title': 'Up Among  The Stars', 'release_year': 2018, 'duration': '86 min', 'type': 'Movie'}
# {'title': 'Alt-Right: Age of Rage', 'release_year': 2018, 'duration': '106 min', 'type': 'Movie'}
# {'title': 'Habibie & Ainun', 'release_year': 2012, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'Nathicharami', 'release_year': 2018, 'duration': '114 min', 'type': 'Movie'}
# {'title': 'Rudy Habibie', 'release_year': 2016, 'duration': '143 min', 'type': 'Movie'}
# {'title': 'Surga Yang Tak Dirindukan', 'release_year': 2015, 'duration': '121 min', 'type': 'Movie'}
# {'title': 'Surga Yang Tak Dirindukan 2', 'release_year': 2017, 'duration': '119 min', 'type': 'Movie'}
# {'title': 'A Taiwanese Tale of Two Cities', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Z Nation', 'release_year': 2018, 'duration': '5 Seasons', 'type': 'TV Show'}
# {'title': 'Goyo: The Boy General', 'release_year': 2018, 'duration': '150 min', 'type': 'Movie'}
# {'title': 'Animas', 'release_year': 2018, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'Black Earth Rising', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Club of Crows', 'release_year': 2019, 'duration': '4 Seasons', 'type': 'TV Show'}
# {'title': 'Examination of Conscience', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Mi Obra Maestra', 'release_year': 2018, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'Polar', 'release_year': 2019, 'duration': '119 min', 'type': 'Movie'}
# {'title': 'The Perfect Match', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Conversations with a Killer: The Ted Bundy Tapes', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Just Love', 'release_year': 2018, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'Innocent', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Close', 'release_year': 2019, 'duration': '95 min', 'type': 'Movie'}
# {'title': 'FYRE: The Greatest Party That Never Happened', 'release_year': 2019, 'duration': '98 min', 'type': 'Movie'}
# {'title': 'IO', 'release_year': 2019, 'duration': '96 min', 'type': 'Movie'}
# {'title': "Marvel's The Punisher", 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Memory Love', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Old Lord Savanna', 'release_year': 2018, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'Patria', 'release_year': 2019, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Soni', 'release_year': 2018, 'duration': '97 min', 'type': 'Movie'}
# {'title': "The World's Most Extraordinary Homes", 'release_year': 2019, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Trigger Warning with Killer Mike', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Abducted in Plain Sight', 'release_year': 2017, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Abdullah, The Final Witness', 'release_year': 2016, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'Adhugo', 'release_year': 2018, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'Echcharikkai', 'release_year': 2018, 'duration': '127 min', 'type': 'Movie'}
# {'title': 'Lavender', 'release_year': 2002, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Pandigai', 'release_year': 2017, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'Pari', 'release_year': 2018, 'duration': '116 min', 'type': 'Movie'}
# {'title': 'Revenger', 'release_year': 2018, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'Sebastian Maniscalco: Stay Hungry', 'release_year': 2019, 'duration': '65 min', 'type': 'Movie'}
# {'title': 'The Doll', 'release_year': 2016, 'duration': '106 min', 'type': 'Movie'}
# {'title': 'The Doll 2', 'release_year': 2017, 'duration': '117 min', 'type': 'Movie'}
# {'title': 'La Grande Chaumière Violette', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Baazaar', 'release_year': 2018, 'duration': '136 min', 'type': 'Movie'}
# {'title': 'All of You', 'release_year': 2017, 'duration': '104 min', 'type': 'Movie'}
# {'title': 'Back with the Ex', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Friends from College', 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Hardy Bucks', 'release_year': 2018, 'duration': '4 Seasons', 'type': 'TV Show'}
# {'title': 'Horrid Henry', 'release_year': 2019, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'ReMastered: Massacre at the Stadium', 'release_year': 2019, 'duration': '65 min', 'type': 'Movie'}
# {'title': 'Solo', 'release_year': 2018, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'The Last Laugh', 'release_year': 2019, 'duration': '99 min', 'type': 'Movie'}
# {'title': 'Pocoyo', 'release_year': 2017, 'duration': '4 Seasons', 'type': 'TV Show'}
# {'title': 'When Heroes Fly', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'GODZILLA The Planet Eater', 'release_year': 2018, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'Next Enti?', 'release_year': 2018, 'duration': '117 min', 'type': 'Movie'}
# {'title': 'Komola Rocket', 'release_year': 2018, 'duration': '95 min', 'type': 'Movie'}
# {'title': 'Nang Nak', 'release_year': 1999, 'duration': '101 min', 'type': 'Movie'}
# {'title': 'And Breathe Normally', 'release_year': 2018, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'El Potro: Unstoppable', 'release_year': 2018, 'duration': '122 min', 'type': 'Movie'}
# {'title': 'Lionheart', 'release_year': 2018, 'duration': '95 min', 'type': 'Movie'}
# {'title': 'See You in Time', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Déjà Vu', 'release_year': 2013, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Monty Python and the Holy Grail', 'release_year': 1975, 'duration': '92 min', 'type': 'Movie'}
# {'title': 'A Series of Unfortunate Events', 'release_year': 2019, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Back to the 90s', 'release_year': 2015, 'duration': '111 min', 'type': 'Movie'}
# {'title': 'COMEDIANS of the world', 'release_year': 2019, 'duration': '13 Seasons', 'type': 'TV Show'}
# {'title': 'Merku Thodarchi Malai', 'release_year': 2018, 'duration': '115 min', 'type': 'Movie'}
# {'title': 'Moshe Kasher: Live in Oakland', 'release_year': 2012, 'duration': '61 min', 'type': 'Movie'}
# {'title': 'Pokémon the Movie: I Choose You!', 'release_year': 2017, 'duration': '97 min', 'type': 'Movie'}
# {'title': 'Puriyatha Puthir', 'release_year': 2017, 'duration': '120 min', 'type': 'Movie'}
# {'title': 'Taramani', 'release_year': 2017, 'duration': '148 min', 'type': 'Movie'}
# {'title': 'The Paper', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Tidying Up with Marie Kondo', 'release_year': 2019, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Whitney Cummings: Money Shot', 'release_year': 2010, 'duration': '48 min', 'type': 'Movie'}
# {'title': 'Bill Hicks: One Night Stand', 'release_year': 1991, 'duration': '28 min', 'type': 'Movie'}
# {'title': 'Bill Hicks: Reflections', 'release_year': 2015, 'duration': '34 min', 'type': 'Movie'}
# {'title': 'Bill Hicks: Relentless', 'release_year': 1992, 'duration': '61 min', 'type': 'Movie'}
# {'title': 'Bill Hicks: Revelations', 'release_year': 1993, 'duration': '56 min', 'type': 'Movie'}
# {'title': 'Bill Hicks: Sane Man', 'release_year': 1989, 'duration': '81 min', 'type': 'Movie'}
# {'title': 'Gina Yashere: Laughing to America', 'release_year': 2013, 'duration': '68 min', 'type': 'Movie'}
# {'title': 'Gina Yashere: Skinny B*tch', 'release_year': 2008, 'duration': '58 min', 'type': 'Movie'}
# {'title': 'Mexicanos de Bronce', 'release_year': 2016, 'duration': '100 min', 'type': 'Movie'}
# {'title': 'Sam Kinison: Breaking the Rules', 'release_year': 1987, 'duration': '50 min', 'type': 'Movie'}
# {'title': 'Sam Kinison: Family Entertainment Hour', 'release_year': 1991, 'duration': '49 min', 'type': 'Movie'}
# {'title': 'Sam Kinison: Live in Vegas', 'release_year': 1991, 'duration': '71 min', 'type': 'Movie'}
# {'title': 'Sam Kinison: The Scream Continues', 'release_year': 2016, 'duration': '29 min', 'type': 'Movie'}
# {'title': 'Secrets in the Hot Spring', 'release_year': 2018, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Taylor Swift reputation Stadium Tour', 'release_year': 2018, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'The Seven Deadly Sins the Movie: Prisoners of the Sky', 'release_year': 2018, 'duration': '100 min', 'type': 'Movie'}
# {'title': 'Tim Allen: Men Are Pigs', 'release_year': 1990, 'duration': '30 min', 'type': 'Movie'}
# {'title': 'Tim Allen: ReWires America', 'release_year': 1991, 'duration': '30 min', 'type': 'Movie'}
# {'title': 'Tim Minchin And The Heritage Orchestra Live', 'release_year': 2011, 'duration': '146 min', 'type': 'Movie'}
# {'title': 'Tim Minchin: So F**king Rock', 'release_year': 2008, 'duration': '127 min', 'type': 'Movie'}
# {'title': 'Todd Glass: Stand-Up Special', 'release_year': 2012, 'duration': '46 min', 'type': 'Movie'}
# {'title': 'Tom Papa Live in New York City', 'release_year': 2011, 'duration': '57 min', 'type': 'Movie'}
# {'title': 'Pioneers: First Women Filmmakers*', 'release_year': 1925, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'In Family We Trust', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'A Twelve Year Night', 'release_year': 2018, 'duration': '122 min', 'type': 'Movie'}
# {'title': 'Black Mirror: Bandersnatch', 'release_year': 2018, 'duration': '312 min', 'type': 'Movie'}
# {'title': 'Hashoter Hatov', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Life Ki Toh Lag Gayi', 'release_year': 2012, 'duration': '109 min', 'type': 'Movie'}
# {'title': 'Murder Mountain', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Selection Day', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Birth Reborn 3', 'release_year': 2018, 'duration': '73 min', 'type': 'Movie'}
# {'title': 'When Angels Sleep', 'release_year': 2018, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'Stand Up and Away! with Brian Regan', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Way Back into Love', 'release_year': 2011, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Watership Down', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': "Demon's Path", 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'People Just Do Nothing', 'release_year': 2018, 'duration': '5 Seasons', 'type': 'TV Show'}
# {'title': 'Single Ladies Senior', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': '7 Days Out', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Bad Seeds', 'release_year': 2018, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'Bird Box', 'release_year': 2018, 'duration': '124 min', 'type': 'Movie'}
# {'title': "Jojo's World", 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'LAST HOPE', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Lion Pride', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Love @ Seventeen', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Perfume', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Sirius the Jaeger', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Struggle: The Life and Lost Art of Szukalski', 'release_year': 2018, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'Wolf', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': '23:59', 'release_year': 2011, 'duration': '78 min', 'type': 'Movie'}
# {'title': 'Aggretsuko: We Wish You a Metal Christmas', 'release_year': 2018, 'duration': '22 min', 'type': 'Movie'}
# {'title': 'Fate/stay night: Unlimited Blade Works', 'release_year': 2015, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Imperfect', 'release_year': 2012, 'duration': '95 min', 'type': 'Movie'}
# {'title': 'Lang Tong', 'release_year': 2015, 'duration': '82 min', 'type': 'Movie'}
# {'title': 'Miss J Contemplates Her Choice', 'release_year': 2014, 'duration': '89 min', 'type': 'Movie'}
# {'title': 'Ascharyachakit!', 'release_year': 2018, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Ellen DeGeneres: Relatable', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Lilli', 'release_year': 2018, 'duration': '85 min', 'type': 'Movie'}
# {'title': 'Prince of Peoria: A Christmas Moose Miracle', 'release_year': 2018, 'duration': '29 min', 'type': 'Movie'}
# {'title': 'Andhadhun', 'release_year': 2018, 'duration': '137 min', 'type': 'Movie'}
# {'title': 'Ashes of Love', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Dragons: Dawn of the Dragon Racers', 'release_year': 2014, 'duration': '27 min', 'type': 'Movie'}
# {'title': 'DreamWorks Holiday Classics', 'release_year': 2011, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Kill the Messenger', 'release_year': 2014, 'duration': '112 min', 'type': 'Movie'}
# {'title': 'Maps to the Stars', 'release_year': 2014, 'duration': '112 min', 'type': 'Movie'}
# {'title': 'Springsteen on Broadway', 'release_year': 2018, 'duration': '153 min', 'type': 'Movie'}
# {'title': 'The Theory of Everything', 'release_year': 2014, 'duration': '123 min', 'type': 'Movie'}
# {'title': 'F.R.E.D.I.', 'release_year': 2018, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Flowers', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Kita Kita', 'release_year': 2017, 'duration': '84 min', 'type': 'Movie'}
# {'title': 'Once in a Lifetime Sessions with George Ezra', 'release_year': 2018, 'duration': '78 min', 'type': 'Movie'}
# {'title': 'Once in a Lifetime Sessions with Kasabian', 'release_year': 2018, 'duration': '79 min', 'type': 'Movie'}
# {'title': 'Once in a Lifetime Sessions with OneRepublic', 'release_year': 2018, 'duration': '73 min', 'type': 'Movie'}
# {'title': 'Once in a Lifetime Sessions with Snow Patrol', 'release_year': 2018, 'duration': '83 min', 'type': 'Movie'}
# {'title': 'Sad Hill Unearthed', 'release_year': 2017, 'duration': '83 min', 'type': 'Movie'}
# {'title': 'Vanjagar Ulagam', 'release_year': 2018, 'duration': '145 min', 'type': 'Movie'}
# {'title': 'Hymn of Death', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Inside the Real Narcos', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'ROMA', 'release_year': 2018, 'duration': '135 min', 'type': 'Movie'}
# {'title': 'The Fix', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'The Innocent Man', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# ...
# {'title': 'Trixie Mattel: Moving Parts', 'release_year': 2019, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'Trophy', 'release_year': 2017, 'duration': '110 min', 'type': 'Movie'}
# {'title': 'Trotsky', 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Troy: The Odyssey', 'release_year': 2017, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'True Grit', 'release_year': 1969, 'duration': '128 min', 'type': 'Movie'}
# {'title': 'True to the Game', 'release_year': 2017, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Trumbo', 'release_year': 2015, 'duration': '124 min', 'type': 'Movie'}
# {'title': 'Tucker and Dale vs. Evil', 'release_year': 2010, 'duration': '89 min', 'type': 'Movie'}
# {'title': 'Tukaram', 'release_year': 2012, 'duration': '162 min', 'type': 'Movie'}
# {'title': 'Tunisian Victory', 'release_year': 1944, 'duration': '76 min', 'type': 'Movie'}
# {'title': 'Turbo', 'release_year': 2013, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'Tusk', 'release_year': 2014, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'Twice', 'release_year': 2010, 'duration': '53 min', 'type': 'Movie'}
# {'title': 'Twin Peaks', 'release_year': 1990, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Twinsanity', 'release_year': 2018, 'duration': '86 min', 'type': 'Movie'}
# {'title': 'Twirlywoos', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Twisted Trunk, Big Fat Body', 'release_year': 2015, 'duration': '89 min', 'type': 'Movie'}
# {'title': 'Two Graves', 'release_year': 2018, 'duration': '80 min', 'type': 'Movie'}
# {'title': 'Two Lovers and a Bear', 'release_year': 2016, 'duration': '95 min', 'type': 'Movie'}
# {'title': 'Tyke Elephant Outlaw', 'release_year': 2015, 'duration': '78 min', 'type': 'Movie'}
# {'title': 'Tyson', 'release_year': 2008, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Ugly', 'release_year': 2013, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'Ugly Duckling', 'release_year': 2015, 'duration': '4 Seasons', 'type': 'TV Show'}
# {'title': 'Una', 'release_year': 2016, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Unaccompanied Minors', 'release_year': 2006, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Unacknowledged', 'release_year': 2017, 'duration': '104 min', 'type': 'Movie'}
# {'title': 'Under an Arctic Sky', 'release_year': 2017, 'duration': '40 min', 'type': 'Movie'}
# {'title': 'Under The Skin', 'release_year': 2013, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Undercover Grandpa', 'release_year': 2016, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Undercover: How to Operate Behind Enemy Lines', 'release_year': 1943, 'duration': '61 min', 'type': 'Movie'}
# {'title': 'Unfinished Song', 'release_year': 2012, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Union Leader', 'release_year': 2017, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'Unruly Friends', 'release_year': 2011, 'duration': '83 min', 'type': 'Movie'}
# {'title': 'Up in the Air', 'release_year': 2009, 'duration': '110 min', 'type': 'Movie'}
# {'title': 'Urvi', 'release_year': 2017, 'duration': '121 min', 'type': 'Movie'}
# {'title': 'Used Goods', 'release_year': 2018, 'duration': '95 min', 'type': 'Movie'}
# {'title': 'USS Indianapolis: Men of Courage', 'release_year': 2016, 'duration': '130 min', 'type': 'Movie'}
# {'title': 'V for Vendetta', 'release_year': 2005, 'duration': '132 min', 'type': 'Movie'}
# {'title': 'V.R. Troopers', 'release_year': 1995, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Vantage Point', 'release_year': 2008, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Veerappan', 'release_year': 2016, 'duration': '117 min', 'type': 'Movie'}
# {'title': 'Veerey Ki Wedding', 'release_year': 2018, 'duration': '130 min', 'type': 'Movie'}
# {'title': 'Vegas Baby', 'release_year': 2016, 'duration': '78 min', 'type': 'Movie'}
# {'title': "Viceroy's House", 'release_year': 2017, 'duration': '106 min', 'type': 'Movie'}
# {'title': 'Victor', 'release_year': 2015, 'duration': '110 min', 'type': 'Movie'}
# {'title': 'Viking Destiny', 'release_year': 2018, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'Vikings Unearthed', 'release_year': 2016, 'duration': '113 min', 'type': 'Movie'}
# {'title': 'Vincent N Roxxy', 'release_year': 2016, 'duration': '101 min', 'type': 'Movie'}
# {'title': 'ViR: The Robot Boy', 'release_year': 2013, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Viswasapoorvam Mansoor', 'release_year': 2017, 'duration': '125 min', 'type': 'Movie'}
# {'title': 'Vitti Dandu', 'release_year': 2014, 'duration': '116 min', 'type': 'Movie'}
# {'title': 'Vizontele Tuuba', 'release_year': 2004, 'duration': '106 min', 'type': 'Movie'}
# {'title': 'Vodka Diaries', 'release_year': 2018, 'duration': '113 min', 'type': 'Movie'}
# {'title': 'Vroomiz', 'release_year': 2016, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'VS.', 'release_year': 2018, 'duration': '99 min', 'type': 'Movie'}
# {'title': 'Waar', 'release_year': 2013, 'duration': '130 min', 'type': 'Movie'}
# {'title': 'Waarrior Savitri', 'release_year': 2016, 'duration': '120 min', 'type': 'Movie'}
# {'title': 'Waiting', 'release_year': 2015, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Waiting...', 'release_year': 2005, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Wake Up', 'release_year': 2017, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Wakefield', 'release_year': 2016, 'duration': '109 min', 'type': 'Movie'}
# {'title': 'Walk with Me', 'release_year': 2017, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Walking Out', 'release_year': 2017, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'War', 'release_year': 2007, 'duration': '103 min', 'type': 'Movie'}
# {'title': 'War Chhod Na Yaar', 'release_year': 2013, 'duration': '109 min', 'type': 'Movie'}
# {'title': 'War Horse', 'release_year': 2011, 'duration': '147 min', 'type': 'Movie'}
# {'title': 'War on Everyone', 'release_year': 2016, 'duration': '98 min', 'type': 'Movie'}
# {'title': 'Warda', 'release_year': 2014, 'duration': '73 min', 'type': 'Movie'}
# {'title': 'Warehoused', 'release_year': 2015, 'duration': '92 min', 'type': 'Movie'}
# {'title': 'Wartime Portraits', 'release_year': 2014, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Water & Power: A California Heist', 'release_year': 2017, 'duration': '78 min', 'type': 'Movie'}
# {'title': 'Waterschool', 'release_year': 2018, 'duration': '68 min', 'type': 'Movie'}
# {'title': 'We Are Your Friends', 'release_year': 2015, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'We Belong Together', 'release_year': 2018, 'duration': '83 min', 'type': 'Movie'}
# {'title': 'We Need to Talk', 'release_year': 2016, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'We the Animals', 'release_year': 2018, 'duration': '93 min', 'type': 'Movie'}
# {'title': 'We, the Marines', 'release_year': 2017, 'duration': '38 min', 'type': 'Movie'}
# {'title': "We're No Animals", 'release_year': 2015, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Weather forecast', 'release_year': 1983, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'Weeds', 'release_year': 2012, 'duration': '8 Seasons', 'type': 'TV Show'}
# {'title': 'Weeds on Fire', 'release_year': 2016, 'duration': '95 min', 'type': 'Movie'}
# {'title': 'Weird Wonders of the World', 'release_year': 2016, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Welcome 2 Karachi', 'release_year': 2015, 'duration': '124 min', 'type': 'Movie'}
# {'title': 'Welcome to Monster High: The Origin Story', 'release_year': 2016, 'duration': '73 min', 'type': 'Movie'}
# {'title': 'Welcome to New York', 'release_year': 2014, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Welcome to Willits', 'release_year': 2017, 'duration': '84 min', 'type': 'Movie'}
# {'title': 'Westerplatte Resists', 'release_year': 1967, 'duration': '93 min', 'type': 'Movie'}
# {'title': 'Westside vs. the World', 'release_year': 2019, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'What a Wonderful Family!', 'release_year': 2017, 'duration': '102 min', 'type': 'Movie'}
# {'title': 'What Happens to My Family', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'What Is Love?', 'release_year': 2012, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'What Lies Beneath', 'release_year': 2000, 'duration': '130 min', 'type': 'Movie'}
# {'title': 'What Makes a Psychopath?', 'release_year': 2017, 'duration': '52 min', 'type': 'Movie'}
# {'title': 'What Still Remains', 'release_year': 2018, 'duration': '91 min', 'type': 'Movie'}
# {'title': "What's Up With Love?", 'release_year': 2002, 'duration': '110 min', 'type': 'Movie'}
# {'title': 'When Calls the Heart', 'release_year': 2017, 'duration': '5 Seasons', 'type': 'TV Show'}
# {'title': 'When Hari Got Married', 'release_year': 2013, 'duration': '75 min', 'type': 'Movie'}
# {'title': 'When Two Worlds Collide', 'release_year': 2016, 'duration': '103 min', 'type': 'Movie'}
# {'title': 'Where the Money Is', 'release_year': 2000, 'duration': '89 min', 'type': 'Movie'}
# {'title': "Where's the Money", 'release_year': 2017, 'duration': '86 min', 'type': 'Movie'}
# {'title': "While We're Young", 'release_year': 2015, 'duration': '97 min', 'type': 'Movie'}
# {'title': 'White Chamber', 'release_year': 2018, 'duration': '89 min', 'type': 'Movie'}
# {'title': 'White Island', 'release_year': 2016, 'duration': '91 min', 'type': 'Movie'}
# {'title': 'Who the F**k Is That Guy?', 'release_year': 2017, 'duration': '78 min', 'type': 'Movie'}
# {'title': "Who's That Knocking at My Door?", 'release_year': 1967, 'duration': '90 min', 'type': 'Movie'}
# {'title': "Who's the One", 'release_year': 2011, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Why Are We Getting So Fat?', 'release_year': 2016, 'duration': '50 min', 'type': 'Movie'}
# {'title': 'Why Knot', 'release_year': 2016, 'duration': '84 min', 'type': 'Movie'}
# {'title': 'Why We Fight: The Battle of Russia', 'release_year': 1943, 'duration': '82 min', 'type': 'Movie'}
# {'title': 'Wild Alaska', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Wild Arabia', 'release_year': 2013, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Wild Wild West', 'release_year': 1999, 'duration': '106 min', 'type': 'Movie'}
# {'title': 'Wildlife', 'release_year': 2018, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'Williams', 'release_year': 2017, 'duration': '105 min', 'type': 'Movie'}
# {'title': 'Willy Wonka & the Chocolate Factory', 'release_year': 1971, 'duration': '100 min', 'type': 'Movie'}
# {'title': 'Winnie', 'release_year': 2017, 'duration': '85 min', 'type': 'Movie'}
# {'title': 'Winsanity', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Winter of Our Dreams', 'release_year': 1981, 'duration': '86 min', 'type': 'Movie'}
# {'title': 'Winter Sun', 'release_year': 2014, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': "Winter's Bone", 'release_year': 2010, 'duration': '100 min', 'type': 'Movie'}
# {'title': 'Wish I Was Here', 'release_year': 2014, 'duration': '106 min', 'type': 'Movie'}
# {'title': 'Wish Man', 'release_year': 2019, 'duration': '108 min', 'type': 'Movie'}
# {'title': 'Withdrawn', 'release_year': 2017, 'duration': '74 min', 'type': 'Movie'}
# {'title': 'Wolves', 'release_year': 2016, 'duration': '109 min', 'type': 'Movie'}
# {'title': 'Women Behind Bars', 'release_year': 2010, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Woodstock', 'release_year': 2019, 'duration': '97 min', 'type': 'Movie'}
# {'title': 'World Trade Center', 'release_year': 2006, 'duration': '129 min', 'type': 'Movie'}
# {'title': "World's Busiest Cities", 'release_year': 2017, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': "World's Weirdest Homes", 'release_year': 2015, 'duration': '49 min', 'type': 'Movie'}
# {'title': 'Would You Rather', 'release_year': 2013, 'duration': '93 min', 'type': 'Movie'}
# {'title': 'Wrong No.', 'release_year': 2015, 'duration': '133 min', 'type': 'Movie'}
# {'title': 'Wrong Side Raju', 'release_year': 2016, 'duration': '140 min', 'type': 'Movie'}
# {'title': 'WWII: Report from the Aleutians', 'release_year': 1943, 'duration': '45 min', 'type': 'Movie'}
# {'title': 'Wyatt Earp', 'release_year': 1994, 'duration': '191 min', 'type': 'Movie'}
# {'title': 'XX', 'release_year': 2017, 'duration': '81 min', 'type': 'Movie'}
# {'title': 'XXx', 'release_year': 2002, 'duration': '124 min', 'type': 'Movie'}
# {'title': 'XXX: State of the Union', 'release_year': 2005, 'duration': '101 min', 'type': 'Movie'}
# {'title': 'Y Tu Mamá También', 'release_year': 2001, 'duration': '106 min', 'type': 'Movie'}
# {'title': 'Y.M.I.: Yeh Mera India', 'release_year': 2008, 'duration': '137 min', 'type': 'Movie'}
# {'title': 'Yaadein', 'release_year': 2001, 'duration': '171 min', 'type': 'Movie'}
# {'title': 'Yaara O Dildaara', 'release_year': 2011, 'duration': '132 min', 'type': 'Movie'}
# {'title': 'Yamla Pagla Deewana 2', 'release_year': 2013, 'duration': '147 min', 'type': 'Movie'}
# {'title': 'Yanda Kartavya Aahe', 'release_year': 2006, 'duration': '151 min', 'type': 'Movie'}
# {'title': 'يوم الدين', 'release_year': 2018, 'duration': '97 min', 'type': 'Movie'}
# {'title': 'Yeh Meri Family', 'release_year': 2018, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Yellowbird', 'release_year': 2014, 'duration': '90 min', 'type': 'Movie'}
# {'title': 'Yes or No', 'release_year': 2010, 'duration': '111 min', 'type': 'Movie'}
# {'title': 'Yes or No 2', 'release_year': 2012, 'duration': '112 min', 'type': 'Movie'}
# {'title': 'Yes or No 2.5', 'release_year': 2015, 'duration': '107 min', 'type': 'Movie'}
# {'title': 'Yo-Kai Watch', 'release_year': 2015, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Yo-Kai Watch: The Movie', 'release_year': 2016, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'Yoga Hosers', 'release_year': 2016, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'Yoko', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Yoko and His Friends', 'release_year': 2015, 'duration': '78 min', 'type': 'Movie'}
# {'title': 'YOM', 'release_year': 2016, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'You Can Tutu', 'release_year': 2017, 'duration': '87 min', 'type': 'Movie'}
# {'title': 'You Can’t Fight Christmas', 'release_year': 2017, 'duration': '85 min', 'type': 'Movie'}
# {'title': 'You Carry Me', 'release_year': 2015, 'duration': '157 min', 'type': 'Movie'}
# {'title': 'You Changed My Life', 'release_year': 2009, 'duration': '116 min', 'type': 'Movie'}
# {'title': "You Don't Mess with the Zohan", 'release_year': 2008, 'duration': '113 min', 'type': 'Movie'}
# {'title': 'Young Adult', 'release_year': 2011, 'duration': '94 min', 'type': 'Movie'}
# {'title': 'Young Tiger', 'release_year': 1973, 'duration': '81 min', 'type': 'Movie'}
# {'title': 'Yours, Mine and Ours', 'release_year': 2005, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'اشتباك', 'release_year': 2016, 'duration': '98 min', 'type': 'Movie'}
# {'title': 'Yu-Gi-Oh! Arc-V', 'release_year': 2015, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Yunus Emre', 'release_year': 2016, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Zak Storm', 'release_year': 2016, 'duration': '3 Seasons', 'type': 'TV Show'}
# {'title': 'Zed Plus', 'release_year': 2014, 'duration': '131 min', 'type': 'Movie'}
# {'title': 'Zenda', 'release_year': 2009, 'duration': '120 min', 'type': 'Movie'}
# {'title': 'Zindagi Gulzar Hai', 'release_year': 2012, 'duration': '1 Season', 'type': 'TV Show'}
# {'title': 'Zinzana', 'release_year': 2015, 'duration': '96 min', 'type': 'Movie'}
# {'title': 'Zodiac', 'release_year': 2007, 'duration': '158 min', 'type': 'Movie'}
# {'title': 'Zombie Dumb', 'release_year': 2018, 'duration': '2 Seasons', 'type': 'TV Show'}
# {'title': 'Zombieland', 'release_year': 2009, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'Zoom', 'release_year': 2006, 'duration': '88 min', 'type': 'Movie'}
# {'title': 'Zubaan', 'release_year': 2015, 'duration': '111 min', 'type': 'Movie'}
